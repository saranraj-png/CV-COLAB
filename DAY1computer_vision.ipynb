# %% [markdown]
# <a href="https://colab.research.google.com/github/saranraj-png/CV-COLAB/blob/main/DAY1computer_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **what will you learn**
# what is an image
#
# how to read and display images
#
# convert images to grayscale
#
# resize and crop images
#
# edge detection

# %%
pip install opencv-python matplotlib

# %%
import cv2

import matplotlib.pyplot as plt

import numpy as np

# %%
# !wget -O sample.jpg https://images.unsplash.com/photo-1518791841217-8f162f1e1131

import cv2

import matplotlib.pyplot as plt

image = cv2.imread("sample.jpg")

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)

plt.title("Original Image")

plt.axis("off")
# Out:
# --2026-03-27 06:40:48--  https://images.unsplash.com/photo-1518791841217-8f162f1e1131
# Resolving images.unsplash.com (images.unsplash.com)... 151.101.2.208, 151.101.66.208, 151.101.130.208, ...
# Connecting to images.unsplash.com (images.unsplash.com)|151.101.2.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1900801 (1.8M) [image/jpeg]
# Saving to: ‘sample.jpg’
#
# sample.jpg          100%[===================>]   1.81M  --.-KB/s    in 0.008s
#
# 2026-03-27 06:40:48 (228 MB/s) - ‘sample.jpg’ saved [1900801/1900801]
# (np.float64(-0.5), np.float64(4271.5), np.float64(2847.5), np.float64(-0.5))

# %%
print("Pixel value at (100,100): ", image[100][100])
# Out:
# Pixel value at (100,100):  [205 202 197]

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')


plt.title("Grayscale Image")

plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(4271.5), np.float64(2847.5), np.float64(-0.5))

# %%
resized=cv2.resize(image,(300,300))
plt.imshow(resized)
plt.title("Resized image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %%
h,w,_=image.shape
crop = image[int(h*0.2):int(h*0.7),int(w*0.2):int(w*0.7)]
import matplotlib.pyplot as plt
plt.imshow(crop)
plt.title("Cropped image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(2135.5), np.float64(1423.5), np.float64(-0.5))

# %%
edge=cv2.Canny(gray,100,200)
plt.imshow(edge,cmap='gray')
plt.title("Edge Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(4271.5), np.float64(2847.5), np.float64(-0.5))
